# %%
a=int(input("請輸入年分"))
if a>1582:
  if a%400==0:
    print("是閏年")
  elif a%4==0 and a%100!=0:
    print("是閏年")
  else:
    print("是平年")
elif a%4==0:
  print("是閏年")
else:
  print("是平年")
# Out:
# 請輸入年分1535
# 是平年
